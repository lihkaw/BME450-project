# %% [markdown]
# <a href="https://colab.research.google.com/github/lihkaw/BME450-project/blob/main/BME_450_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # BME 450 Final Project
# Predicting Infant Emotion based on Crying Audio

# %%
# Import nessecary libaries
import torch
from torch import nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchaudio import datasets, transforms
import matplotlib.pyplot as plt
from google.colab import drive

# Import dataset
drive.mount('/content/drive')
Train_d = "/content/drive/MyDrive/BME 450/Project/datasets/Train"
Test_d  = "/content/drive/MyDrive/BME 450/Project/datasets/Test"
